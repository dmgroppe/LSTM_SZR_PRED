# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, SimpleRNN, Activation, Dropout
from keras.layers import CuDNNGRU
from keras.optimizers import RMSprop, SGD
from keras.constraints import max_norm

model_fname='/home/dgroppe/GIT/LSTM_SZR_PRED/MODELS/GruFf_0b/cuda_gru_epoched.h5'
model=load_model(model_fname)
#model.summary()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/TFLOW_VE3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# ~/TFLOW_VE3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1304       # Ensure any changes to the graph are reflected in the runtime.
# -> 1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
#
# ~/TFLOW_VE3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1339       with self._graph._lock:  # pylint: disable=protected-access
# -> 1340         tf_session.ExtendSession(self._session)
#    1341     else:
#
# ...

# %%
# Load data from DNN
dnn=np.load('filtered_test_data.npz')
print(dnn.keys())
test_ids=dnn['test_ids']
n_wind=dnn['n_wind']
# Out:
# ['model_name', 'test_ids', 'eeg_yhat', 'eeg_y', 'art_yhat', 'art_y', 'n_wind']

# %%
# Load original MATLAB data
in_fname = 'SAMPLE_DATA/GRU_DATA/p3_epoched_blink_group.mat'
mat = sio.loadmat(in_fname)
print(mat.keys())

# Get first chan and normalize
raw = np.squeeze(mat['raw_eeg'][0, :, :])
clean = np.squeeze(mat['cleaned_eeg'][0, :, :])
art = np.squeeze(mat['blink_eeg'][0, :, :])
blink_class=np.squeeze(mat['blink_class'][test_ids]) # 1=blink trial, 0=non-blink trial
print(blink_class.shape)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'blink_class', 'blink_eeg', 'cleaned_eeg', 'raw_eeg', 'srate', 'use_elecs'])
# (1010,)

# %%
mid_wind=int(np.ceil(n_wind/2))
time_subset_ids=np.arange(mid_wind,raw.shape[0]-mid_wind+1)
print(len(time_subset_ids))
print(dnn['eeg_y'].shape)
times=np.arange(0,len(time_subset_ids))/mat['srate']
times=times[0]
print(len(times))
# Out:
# 218
# (218, 1010)
# 218

# %%
# Compute reconstructed EEG for all test trials
n_test_id=len(test_ids)
recon=np.zeros(dnn['eeg_y'].shape)
for id in range(n_test_id):
    recon[:,id]=raw[time_subset_ids,test_ids[id]]-dnn['art_yhat'][:,id]

# %%
id=1
if blink_class[id]==1:
    print('BLINK TRIAL')
else:
    print('NON-BLINK TRIAL')

#recon=raw[time_subset_ids,test_ids[id]]-dnn['art_yhat'][:,id]
plt.figure(1)
plt.clf()
plt.plot(times,clean[time_subset_ids,test_ids[id]],label='y_mat')
plt.plot(times,dnn['eeg_y'][:,id],'--',label='y_npz')
plt.plot(times,dnn['eeg_yhat'][:,id],'--',label='yhat_npz')
plt.plot(times,recon[:,id],'--',label='recon')
plt.legend()
plt.ylabel('uV')
plt.xlabel('sec')
plt.title('Artifact Corrected EEG')

plt.figure(2)
plt.clf()
plt.plot(times,art[time_subset_ids,test_ids[id]],label='y_mat')
plt.plot(times,dnn['art_y'][:,id],'--',label='y_npz')
plt.plot(times,dnn['art_yhat'][:,id],'--',label='yhat_npz')
plt.legend()
plt.ylabel('uV')
plt.xlabel('sec')
plt.title('Artifact Component')

# Plot raw (potentially artifact laden) data
plt.figure(3)
plt.clf()
plt.plot(times,raw[time_subset_ids,test_ids[id]],label='y_mat')
plt.plot(times,dnn['art_y'][:,id]+dnn['eeg_y'][:,id],'--',label='y_npz')
plt.plot(times,dnn['art_yhat'][:,id]+dnn['eeg_yhat'][:,id],'--',label='yhat_npz')
plt.legend()
plt.ylabel('uV')
plt.xlabel('sec')
plt.title('Raw EEG')
# Out:
# BLINK TRIAL
# Text(0.5,1,'Raw EEG')

# %%
# Compute variance accounted for; 1-sse/ss
ss=np.zeros(3)
recon_sse=np.zeros(3)
sse=np.zeros(3)
recon_mn_abs_err=np.zeros(3)
mn_abs_err=np.zeros(3)
recon_md_abs_err=np.zeros(3)
md_abs_err=np.zeros(3)
for a in range(3):
    if a==0:
        use_ids=np.arange(0,n_test_id)
    elif a==1:
        use_ids=blink_class>0
    else:
        use_ids=blink_class==0
    ss[a]=np.sum(np.square(dnn['eeg_y'][:,use_ids]))
    recon_sse[a]=np.sum(np.square(dnn['eeg_y'][:,use_ids]-recon[:,use_ids]))
    sse[a]=np.sum(np.square(dnn['eeg_y'][:,use_ids]-dnn['eeg_yhat'][:,use_ids]))
    recon_mn_abs_err[a]=np.mean(np.abs(dnn['eeg_y'][:,use_ids]-recon[:,use_ids]))
    mn_abs_err[a]=np.mean(np.abs(dnn['eeg_y'][:,use_ids]-dnn['eeg_yhat'][:,use_ids]))
    recon_md_abs_err[a]=np.median(np.abs(dnn['eeg_y'][:,use_ids]-recon[:,use_ids]))
    md_abs_err[a]=np.median(np.abs(dnn['eeg_y'][:,use_ids]-dnn['eeg_yhat'][:,use_ids]))
# sse=0.0
# recon_sse=0.0
# ss=0.0
# for a in range(n_test_id):
#     ss+=np.sum(np.square(dnn['eeg_y'][:,a]))
#     recon_sse+=np.sum(np.square(dnn['eeg_y'][:,a]-recon[:,a]))
#     sse+=np.sum(np.square(dnn['eeg_y'][:,a]-dnn['eeg_yhat'][:,a]))
    #,'--',label='y_npz')
#plt.plot(times,dnn['eeg_yhat'][:,id],'--',label='yhat_npz') 
print(ss[0])
print(recon_sse[0])
print(sse[0])
# Out:
# 22858114.674440935
# 12994670.543549921
# 13945163.932800964

# %%
dnn['eeg_y'].shape
# Out:
# (218, 1010)

# %%
dnn.keys()
22858114.67444096
12994670.54354994
13945163.932800956
# Out:
# ['model_name', 'test_ids', 'eeg_yhat', 'eeg_y', 'art_yhat', 'art_y', 'n_wind']

# %%
for a in range(3):
    if a==0:
        print('** All Trials **')
    elif a==1:
        print('** Blink Trials **')
    else:
        print('** Non-Blink Trials **')
    print('Recon pptn variance acc for: %f' % (1-recon_sse[a]/ss[a]))
    print('Simple DNN pptn variance acc for: %f' % (1-sse[a]/ss[a]))
    print('Recon mean absolute err %f uV' % recon_mn_abs_err[a])
    print('Simple DNN mean absolute err %f uV' % mn_abs_err[a])
    print('Recon median absolute err %f uV' % recon_md_abs_err[a])
    print('Simple DNN median absolute err %f uV' % md_abs_err[a])
    print(' ')
# Out:
# ** All Trials **
# Recon pptn variance acc for: 0.431507
# Simple DNN pptn variance acc for: 0.389925
# Recon mean absolute err 4.990052 uV
# Simple DNN mean absolute err 5.725919 uV
# Recon median absolute err 3.229684 uV
# Simple DNN median absolute err 4.390141 uV
#
# ** Blink Trials **
# Recon pptn variance acc for: 0.034228
# Simple DNN pptn variance acc for: 0.049148
# Recon mean absolute err 6.892229 uV
# Simple DNN mean absolute err 7.443545 uV
# Recon median absolute err 4.078314 uV
# Simple DNN median absolute err 5.394313 uV
#
# ** Non-Blink Trials **
# Recon pptn variance acc for: 0.760242
# Simple DNN pptn variance acc for: 0.671906
# Recon mean absolute err 3.624885 uV
# Simple DNN mean absolute err 4.493201 uV
# Recon median absolute err 2.840050 uV
# Simple DNN median absolute err 3.857170 uV

# %%
import mtspec
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-d1b16150fab4> in <module>()
# ----> 1 import mtspec
#
# ModuleNotFoundError: No module named 'mtspec'

# %%
plt.figure(1)
plt.clf()
plt.plot(np.sin(grd))

# %%
x_z = preprocessing.scale(x)
print(x_z)
print(np.mean(x_z))
print(np.std(x_z))
# Out:
# [-1.5666989  -1.21854359 -0.87038828 -0.52223297 -0.17407766  0.17407766
#   0.52223297  0.87038828  1.21854359  1.5666989 ]
# -6.661338147750939e-17
# 1.0
# /Users/davidgroppe/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
scaler = preprocessing.StandardScaler().fit(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-165a838a352d> in <module>()
# ----> 1 scaler = preprocessing.StandardScaler().fit(x)
#
# ~/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# --> 590         return self.partial_fit(X, y)
#     591
#     592     def partial_fit(self, X, y=None):
#
# ~/anaconda/lib/python3.5/site-packages/sklearn/preprocessing/data.py in partial_fit(self, X, y)
#     610         """
#     611         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
# --> 612                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES)
#     613
#     614         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ...

# %%
# >>> scaler = preprocessing.StandardScaler().fit(X_train)
# >>> scaler
# StandardScaler(copy=True, with_mean=True, with_std=True)

# >>> scaler.mean_                                      
# array([ 1. ...,  0. ...,  0.33...])

# >>> scaler.scale_                                       
# array([ 0.81...,  0.81...,  1.24...])

# >>> scaler.transform(X_train)                           
# array([[ 0.  ..., -1.22...,  1.33...],
#        [ 1.22...,  0.  ..., -0.26...],
#        [-1.22...,  1.22..., -1.06...]])
